# %%
import pandas as pd
import numpy as np
import random

# %%
food_data = pd.read_csv("ORS Data/food_data.csv", index_col = 0)

# %%
food_data
# Out:
#                                                  FoodName          Cuisine
# FoodID
# 1                                    Masala Karela Recipe           Indian
# 2       Hariyali Egg Curry Recipe In Coriander and Min...           Indian
# 3       Gourd Raita Recipe - Grated Bottle Gourd Yogur...           Indian
# 4       Kesar Mango Lassi Recipe - Saffron Mango Lassi...           Indian
# 5       Spinach Garlic Bruschetta Recipe With Red Bell...  Italian Recipes
# 6                   Chinese Darsaan Recipe With Ice Cream          Chinese
# 7               Dalia Pakora Recipe - Dalia Pakora Recipe           Indian
# 8                      Spicy Chilli Garlic Noodles Recipe            Asian
# 9                   Cheesy Garlic Broccoli Nuggets Recipe           Indian
# 10      Singapore Style Chicken Layered Fried Rice Recipe            Asian
# 11                                      Tofu Pulao Recipe           Indian
# 12                                     Radish Soup Recipe           Indian
# 13                    Crunchy Ginger Capsicum Rice Recipe           Indian
# 14      Shanghai Style Chap Nian Gao Recipes (Stir Fri...          Chinese
# 15                   Elephant Yam Raita (Recipe In Hindi)           Indian
# 16                       Spicy Lemon Chicken Kebab Recipe           Indian
# 17      Basil Tincture Recipe (Or) - Herbal Drink From...           Indian
# 18                       Cheese Stuffed Aloo Bonda Recipe           Indian
# 19                Pudina Mushroom And Soya Biryani Recipe           Indian
# 20      PF Chang's Style Crispy Chicken Lettuce Wraps ...            Asian
# 21      Wheat Grass Shikanji - Wheat Grass Lemonade Re...           Indian
# 22             Cauliflower Matar Bhurji (Recipe in Hindi)           Indian
# 23                        Aromatic Vegetable Pulao Recipe           Indian
# 24             Spicy Curd Recipe - Spicy Curd With Onions           Indian
# 25                         Mustard Vegetable Curry Recipe           Indian
# 26      One Pot Spicy Vegetable Pulao Recipe with Coco...           Indian
# 27      Moong Dal Khichdi Recipe For Babies And Toddle...           Indian
# 28                      Vegetable Fried Brown Rice Recipe          Chinese
# 29                        Crispy Chicken Dumplings Recipe           Indian
# 30       Moon Biscuits Recipe (Moon Shaped Baked Cookies)           Indian
# 31                       Aloo Matar Masala Khichdi Recipe           Indian
# 32               Rock Toast Recipe - Semolina Bread Toast           Indian
# 33      Classic Grilled Tomato Cucumber Chutney Sandwi...           Indian
# 34      Raw Mango Murabba Recipe - Cinnamon Spiced Man...           Indian
# 35                         Royal Bread Gulab Jamun Recipe           Indian
# 36      Safed Achari Baingan Recipe - White Aubergine ...           Indian
# 37      Karela Dahi Puri Recipe - A Chatpata Chaat Mad...           Indian
# 38      Tomato Chicken Roast Recipe Flavoured With Kas...           Indian
# 39      Nellikai Oorugai / Amla Sambhario Recipe (Inst...           Indian
# 40                                Kaju Badam Ladoo Recipe           Indian
# 41      Spaghetti Aglio Olio With Parmesan & Greens Re...  Italian Recipes
# 42         Mushroom Dumpling Recipe With Potatoes (Momos)            Asian
# 43      Banana Pomegranate Raita Recipe - Kela Anar Raita           Indian
# 44         Dhania Wale Aloo Recipe - Coriander Potato Dry           Indian
# 45                        Tender Coconut Ice Cream Recipe           Indian
# 46                         Milk Powder Chena Burfi Recipe           Indian
# 47      Carrot Orange Walnut Raita (Fruity Nutty Yogur...           Indian
# 48                           Bamboo Shoot Stir Fry Recipe            Asian
# 49            Till Wale Aloo Recipe - Sesame Potato Sabzi           Indian
# 50            Spirulina and Mint Basil Pesto Pasta Recipe  Italian Recipes
# 51      Til Moongphali Aur Kundru Sabzi Recipe - Sesam...           Indian
# 52                            Leftover Roti Cutlet Recipe           Indian
# 53      Asian Style Baby Corn With Sesame Seeds and Pe...            Asian
# 54               Sprouted Moong And Onion Fritters Recipe           Indian
# 55                                Corn only quiche recipe           Indian
# 56                       Masala Cornflakes Chicken Recipe           Indian
# 57         One Pot Methi Mushroom Brown Rice Pulao Recipe           Indian

# %%
ratings_df = pd.read_csv("ORS Data/food_rating.csv", index_col = 0)

# %%
ratings_df
# Out:
# Empty DataFrame
# Columns: [FoodID, UserID, rating, timestamp]
# Index: []

# %%
FoodID = [random.randint(1, 57) for _ in range(1000)]

# %%
FoodID
# Out:
# [21,
#  18,
#  36,
#  40,
#  14,
#  5,
#  50,
#  27,
#  52,
#  5,
#  21,
#  40,
#  32,
#  9,
#  53,
#  41,
#  49,
#  40,
#  27,
#  10,
#  32,
#  7,
#  36,
#  21,
#  3,
#  33,
#  57,
#  54,
#  5,
#  8,
#  55,
#  44,
#  13,
#  16,
#  29,
#  2,
#  11,
#  16,
#  39,
#  37,
#  27,
#  29,
#  2,
#  54,
#  39,
#  44,
#  20,
#  43,
#  18,
#  31,
#  29,
#  13,
#  21,
#  19,
#  12,
#  29,
#  34,
#  46,
#  43,
#  37,
#  15,
#  4,
#  42,
#  26,
#  43,
#  39,
#  37,
#  16,
#  6,
#  20,
#  57,
#  16,
#  51,
#  17,
#  2,
#  22,
#  28,
#  34,
#  7,
#  4,
#  54,
#  57,
#  24,
#  33,
#  31,
#  45,
#  51,
#  22,
#  14,
#  34,
#  8,
#  38,
#  35,
#  46,
#  21,
#  54,
#  15,
#  52,
#  17,
#  23,
#  2,
#  32,
#  16,
#  13,
#  37,
#  7,
#  47,
#  44,
#  57,
#  57,
#  7,
#  48,
#  18,
#  27,
#  39,
#  36,
#  37,
#  41,
#  47,
#  44,
#  42,
#  17,
#  13,
#  27,
#  13,
#  10,
#  36,
#  45,
#  31,
#  20,
#  31,
#  31,
#  44,
#  11,
#  46,
#  57,
#  51,
#  20,
#  41,
#  19,
#  46,
#  20,
#  17,
#  15,
#  15,
#  49,
#  16,
#  27,
#  12,
#  33,
#  33,
#  46,
#  32,
#  29,
#  45,
#  54,
#  27,
#  36,
#  31,
#  50,
#  16,
#  30,
#  36,
#  3,
#  55,
#  18,
#  47,
#  3,
#  12,
#  35,
#  39,
#  37,
#  57,
#  37,
#  11,
#  17,
#  48,
#  24,
#  52,
#  54,
#  3,
#  14,
#  1,
#  4,
#  45,
#  9,
#  10,
#  31,
#  17,
#  57,
#  47,
#  1,
#  29,
#  19,
#  26,
#  5,
#  21,
#  27,
#  14,
#  17,
#  49,
#  41,
#  3,
#  45,
#  20,
#  34,
#  23,
#  1,
#  38,
#  22,
#  29,
#  46,
#  11,
#  1,
#  56,
#  5,
#  34,
#  10,
#  33,
#  57,
#  49,
#  47,
#  34,
#  17,
#  18,
#  49,
#  39,
#  56,
#  41,
#  33,
#  48,
#  16,
#  5,
#  35,
#  48,
#  22,
#  57,
#  39,
#  32,
#  48,
#  51,
#  20,
#  46,
#  11,
#  33,
#  4,
#  22,
#  44,
#  44,
#  34,
#  51,
#  18,
#  36,
#  41,
#  11,
#  40,
#  1,
#  52,
#  3,
#  8,
#  42,
#  36,
#  18,
#  22,
#  28,
#  50,
#  4,
#  23,
#  29,
#  17,
#  52,
#  57,
#  3,
#  44,
#  56,
#  3,
#  27,
#  19,
#  2,
#  54,
#  4,
#  27,
#  40,
#  21,
#  5,
#  12,
#  29,
#  2,
#  44,
#  16,
#  9,
#  41,
#  13,
#  15,
#  30,
#  17,
#  22,
#  7,
#  5,
#  40,
#  10,
#  4,
#  22,
#  25,
#  37,
#  30,
#  40,
#  46,
#  56,
#  35,
#  21,
#  42,
#  3,
#  24,
#  55,
#  30,
#  53,
#  49,
#  29,
#  37,
#  15,
#  18,
#  18,
#  15,
#  33,
#  41,
#  2,
#  39,
#  1,
#  48,
#  7,
#  29,
#  42,
#  44,
#  4,
#  33,
#  53,
#  34,
#  39,
#  35,
#  5,
#  29,
#  37,
#  32,
#  2,
#  52,
#  40,
#  15,
#  20,
#  17,
#  30,
#  3,
#  10,
#  22,
#  31,
#  50,
#  5,
#  31,
#  35,
#  39,
#  1,
#  41,
#  24,
#  29,
#  55,
#  43,
#  27,
#  10,
#  20,
#  46,
#  55,
#  46,
#  56,
#  25,
#  16,
#  24,
#  19,
#  43,
#  31,
#  32,
#  20,
#  11,
#  26,
#  13,
#  49,
#  53,
#  39,
#  10,
#  6,
#  11,
#  49,
#  16,
#  15,
#  49,
#  28,
#  49,
#  13,
#  35,
#  27,
#  45,
#  43,
#  46,
#  11,
#  26,
#  19,
#  36,
#  30,
#  29,
#  29,
#  27,
#  10,
#  53,
#  40,
#  23,
#  36,
#  40,
#  54,
#  1,
#  21,
#  49,
#  4,
#  48,
#  6,
#  16,
#  34,
#  56,
#  14,
#  17,
#  40,
#  22,
#  23,
#  38,
#  29,
#  44,
#  47,
#  15,
#  31,
#  6,
#  50,
#  3,
#  29,
#  50,
#  16,
#  43,
#  51,
#  52,
#  48,
#  10,
#  20,
#  9,
#  23,
#  9,
#  3,
#  22,
#  55,
#  51,
#  46,
#  23,
#  57,
#  40,
#  15,
#  45,
#  22,
#  6,
#  57,
#  17,
#  42,
#  54,
#  19,
#  35,
#  5,
#  20,
#  16,
#  35,
#  41,
#  56,
#  42,
#  20,
#  27,
#  27,
#  40,
#  23,
#  16,
#  43,
#  31,
#  24,
#  35,
#  48,
#  47,
#  28,
#  43,
#  16,
#  26,
#  12,
#  4,
#  9,
#  20,
#  36,
#  11,
#  11,
#  54,
#  12,
#  20,
#  53,
#  17,
#  5,
#  52,
#  20,
#  50,
#  52,
#  40,
#  3,
#  10,
#  23,
#  10,
#  17,
#  13,
#  45,
#  21,
#  51,
#  24,
#  37,
#  31,
#  41,
#  22,
#  45,
#  24,
#  52,
#  19,
#  33,
#  18,
#  35,
#  10,
#  5,
#  35,
#  7,
#  1,
#  31,
#  13,
#  18,
#  50,
#  43,
#  40,
#  14,
#  14,
#  22,
#  54,
#  32,
#  56,
#  6,
#  51,
#  24,
#  35,
#  55,
#  34,
#  5,
#  34,
#  28,
#  20,
#  26,
#  32,
#  6,
#  57,
#  12,
#  5,
#  50,
#  20,
#  36,
#  1,
#  7,
#  41,
#  40,
#  47,
#  32,
#  54,
#  55,
#  9,
#  13,
#  56,
#  28,
#  56,
#  15,
#  24,
#  24,
#  39,
#  39,
#  22,
#  16,
#  5,
#  33,
#  12,
#  6,
#  35,
#  36,
#  40,
#  49,
#  43,
#  16,
#  24,
#  14,
#  12,
#  40,
#  2,
#  4,
#  37,
#  48,
#  14,
#  11,
#  19,
#  28,
#  10,
#  22,
#  21,
#  24,
#  13,
#  46,
#  5,
#  47,
#  6,
#  16,
#  14,
#  43,
#  15,
#  48,
#  9,
#  45,
#  20,
#  4,
#  26,
#  26,
#  38,
#  18,
#  50,
#  7,
#  10,
#  29,
#  13,
#  43,
#  9,
#  23,
#  4,
#  19,
#  26,
#  7,
#  30,
#  33,
#  5,
#  53,
#  43,
#  34,
#  35,
#  49,
#  10,
#  53,
#  35,
#  20,
#  26,
#  19,
#  22,
#  33,
#  32,
#  22,
#  45,
#  40,
#  41,
#  35,
#  3,
#  56,
#  1,
#  44,
#  38,
#  50,
#  14,
#  44,
#  18,
#  55,
#  37,
#  28,
#  39,
#  41,
#  41,
#  49,
#  32,
#  48,
#  4,
#  57,
#  28,
#  54,
#  15,
#  11,
#  33,
#  17,
#  5,
#  2,
#  6,
#  32,
#  7,
#  12,
#  42,
#  27,
#  45,
#  6,
#  19,
#  5,
#  57,
#  36,
#  42,
#  40,
#  43,
#  11,
#  1,
#  26,
#  54,
#  37,
#  17,
#  18,
#  48,
#  51,
#  39,
#  2,
#  48,
#  16,
#  38,
#  35,
#  55,
#  55,
#  55,
#  26,
#  41,
#  31,
#  2,
#  25,
#  29,
#  11,
#  47,
#  39,
#  53,
#  19,
#  1,
#  45,
#  25,
#  1,
#  23,
#  55,
#  9,
#  20,
#  10,
#  21,
#  41,
#  46,
#  17,
#  38,
#  10,
#  1,
#  53,
#  36,
#  30,
#  37,
#  23,
#  44,
#  38,
#  1,
#  30,
#  12,
#  49,
#  49,
#  16,
#  21,
#  28,
#  43,
#  9,
#  33,
#  32,
#  25,
#  54,
#  23,
#  34,
#  13,
#  52,
#  48,
#  16,
#  12,
#  8,
#  9,
#  46,
#  29,
#  56,
#  56,
#  25,
#  33,
#  55,
#  24,
#  7,
#  11,
#  50,
#  10,
#  56,
#  2,
#  22,
#  25,
#  38,
#  3,
#  2,
#  2,
#  49,
#  55,
#  35,
#  13,
#  55,
#  43,
#  34,
#  38,
#  22,
#  40,
#  9,
#  13,
#  3,
#  34,
#  31,
#  7,
#  56,
#  42,
#  25,
#  18,
#  44,
#  4,
#  43,
#  56,
#  12,
#  15,
#  53,
#  3,
#  8,
#  37,
#  12,
#  11,
#  29,
#  5,
#  53,
#  13,
#  22,
#  54,
#  1,
#  24,
#  46,
#  8,
#  25,
#  36,
#  2,
#  46,
#  42,
#  48,
#  23,
#  50,
#  9,
#  49,
#  32,
#  38,
#  57,
#  13,
#  20,
#  16,
#  9,
#  27,
#  36,
#  56,
#  47,
#  33,
#  8,
#  5,
#  38,
#  30,
#  48,
#  32,
#  40,
#  54,
#  44,
#  57,
#  22,
#  17,
#  47,
#  37,
#  23,
#  17,
#  46,
#  15,
#  47,
#  18,
#  31,
#  7,
#  26,
#  24,
#  23,
#  50,
#  4,
#  48,
#  57,
#  4,
#  46,
#  37,
#  6,
#  1,
#  43,
#  32,
#  3,
#  22,
#  2,
#  40,
#  57,
#  8,
#  51,
#  25,
#  53,
#  16,
#  42,
#  3,
#  46,
#  23,
#  52,
#  52,
#  10,
#  55,
#  13,
#  47,
#  15,
#  56,
#  42,
#  13,
#  18,
#  14,
#  20,
#  1,
#  8,
#  5,
#  32,
#  26,
#  6,
#  43,
#  3,
#  1,
#  22,
#  14,
#  26,
#  18,
#  33,
#  45,
#  11,
#  51,
#  2,
#  34,
#  41,
#  31,
#  23,
#  28,
#  24,
#  4,
#  51,
#  57,
#  55,
#  20,
#  33,
#  49,
#  31,
#  41,
#  46,
#  35,
#  9,
#  1,
#  42,
#  14,
#  42,
#  27,
#  55,
#  27,
#  28,
#  46,
#  2,
#  39,
#  37,
#  46,
#  34,
#  37,
#  35,
#  37,
#  16,
#  53,
#  35,
#  52,
#  14,
#  43,
#  39,
#  44,
#  41,
#  53,
#  35,
#  41,
#  33,
#  1,
#  27,
#  32]

# %%
UserID = [random.randint(1, 20) for _ in range(1000)]

# %%
rating = [random.randint(1, 5) for _ in range(1000)]

# %%
rating

# %%
ratings_df["FoodID"] = FoodID

# %%
ratings_df["UserID"] = UserID
ratings_df["rating"] = rating

# %%
ratings_df.drop("timestamp", axis = 1)
# Out:
#      FoodID  UserID  rating
# 0        21      13       4
# 1        18      15       5
# 2        36      13       2
# 3        40      11       4
# 4        14      12       5
# ..      ...     ...     ...
# 995      41      14       2
# 996      33       9       2
# 997       1      20       5
# 998      27       4       1
# 999      32       1       3
#
# [1000 rows x 3 columns]

# %%
ratings_df.to_csv("ORS Data/food_rating.csv", index = False)

# %%
ratings_df
# Out:
#      FoodID  UserID  rating timestamp
# 0        21      13       4       NaN
# 1        18      15       5       NaN
# 2        36      13       2       NaN
# 3        40      11       4       NaN
# 4        14      12       5       NaN
# ..      ...     ...     ...       ...
# 995      41      14       2       NaN
# 996      33       9       2       NaN
# 997       1      20       5       NaN
# 998      27       4       1       NaN
# 999      32       1       3       NaN
#
# [1000 rows x 4 columns]

# %%
tags_df = pd.read_csv("ORS Data/food_tags.csv", index_col = 0)

# %%
tags_df
# Out:
# Empty DataFrame
# Columns: [UserID, FoodID, tag, Timestamp]
# Index: []

# %%
tags_df["UserID"] = UserID
tags_df["FoodID"] = FoodID

# %%
tags = ["Tasty", "wonderful", "wow", "so good", "amazing"]*200

# %%
tags
# Out:
# ['Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing',
#  'Tasty',
#  'wonderful',
#  'wow',
#  'so good',
#  'amazing']

# %%
tags_df["tag"] = tags

# %%
tags_df.drop(["Timestamp", "FoodOD"], axis = 1)
# Out:
#      UserID  FoodID        tag
# 0        13      21      Tasty
# 1        15      18  wonderful
# 2        13      36        wow
# 3        11      40    so good
# 4        12      14    amazing
# ..      ...     ...        ...
# 995      14      41      Tasty
# 996       9      33  wonderful
# 997      20       1        wow
# 998       4      27    so good
# 999       1      32    amazing
#
# [1000 rows x 3 columns]

# %%
tags_df.to_csv("ORS Data/Food_tags.csv", index = False)
